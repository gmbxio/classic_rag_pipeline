# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure

from langchain_core.documents import Document

doc = Document(
    page_content="This is the content of the page.",
    metadata={"source": "example.txt", "author": "gmb"}
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'author': 'gmb'}, page_content='This is the content of the page.')

# %%
# creating a simple txt file using cli
import os
os.makedirs("../data/texts", exist_ok = True)

# %%
# creating a simple txt file using python
sample_texts = {
    "../data/texts/example.txt": "This is an example text file created using Python.",
    "../data/texts/another_example.txt": "This is another example text file created using Python."
}

for file_path, content in sample_texts.items():
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(content)
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
# text loaders
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/texts/example.txt", encoding = "utf-8")
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/texts/example.txt'}, page_content='This is an example text file created using Python.')]

# %%
# Directory Loader for .txt files
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/texts",
    glob = "*.txt",
    loader_cls= TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress= False
)
dir_documents = dir_loader.load()
dir_documents
# Out:
# [Document(metadata={'source': '../data/texts/another_example.txt'}, page_content='This is another example text file created using Python.'),
#  Document(metadata={'source': '../data/texts/example.txt'}, page_content='This is an example text file created using Python.')]

# %%
# Directory Loader for pdf files
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader
pdf_dir_documents = DirectoryLoader(
    "../data/pdfs",
    glob = "*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress= False
)
pdf_document = pdf_dir_documents.load()
pdf_document
# Out:
# [Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '../data/pdfs/1st Year Grade Cards.pdf', 'file_path': '../data/pdfs/1st Year Grade Cards.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content=''),
#  Document(metadata={'producer': '', 'creator': '', 'creationdate': '', 'source': '../data/pdfs/1st Year Grade Cards.pdf', 'file_path': '../data/pdfs/1st Year Grade Cards.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, page_content=''),
# ...
